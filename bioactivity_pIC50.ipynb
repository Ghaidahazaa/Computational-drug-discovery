# %%
# Install RDKit and dependencies
# !apt-get install -y python3-rdkit
# Out:
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-private.so.0.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-pkg.so.6.0)

# %%
# Install RDKit and dependencies
# !apt-get install -y python3-rdkit
# !apt-get update # Update package lists
# !apt-get install -y libstdc++6 # Install or upgrade libstdc++6
# Out:
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-private.so.0.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-pkg.so.6.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-private.so.0.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-pkg.so.6.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-private.so.0.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-pkg.so.6.0)

# %%
# Find the path to your libstdc++.so.6 (usually within anaconda or similar env)
# !find / -name "libstdc++.so.6" -print

# Assuming you find the desired version at /path/to/your/libstdc++.so.6
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/path/to/your/
# Out:
# /usr/lib/x86_64-linux-gnu/libstdc++.so.6
# /usr/lib32/libstdc++.so.6
# /usr/local/lib/libstdc++.so.6
# /usr/local/x86_64-conda_cos6-linux-gnu/sysroot/lib/libstdc++.so.6
# /usr/local/pkgs/libstdcxx-ng-9.1.0-hdf63c60_0/lib/libstdc++.so.6
# /usr/local/pkgs/libstdcxx-ng-9.1.0-hdf63c60_0/x86_64-conda_cos6-linux-gnu/sysroot/lib/libstdc++.so.6
# /opt/nvidia/nsight-compute/2023.2.2/host/linux-desktop-glibc_2_11_3-x64/libstdc++.so.6
# find: ‘/proc/68/task/68/net’: Invalid argument
# find: ‘/proc/68/net’: Invalid argument
# find: ‘/proc/28658/task/28658/net’: Invalid argument
# find: ‘/proc/28658/net’: Invalid argument
# find: ‘/content/gdrive’: Transport endpoint is not connected

# %%
# Use this code to check if you can import RDKit
import sys
# !{sys.executable} -m pip install --upgrade pip  # Ensure pip is up to date
# !{sys.executable} -m pip install rdkit  # Install RDKit

# %%
# !apt-get install -y libstdc++6
# Out:
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-private.so.0.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-pkg.so.6.0)

# %% [markdown]
# #Install consa ad rdkit

# %% [markdown]
# # Load bioacitviy data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/"
# Out:
# 'Colab Notebooks'  'stc TV Data Set_T1.xlsb'

# %%
! ls
# Out:
# drive				       plot_ic50.pdf
# gdrive				       plot_MW_vs_LogP.pdf
# mannwhitneyu_pIC50.csv		       plot_MW_vs_LogP_with_intermediate.pdf
# Miniconda3-py37_4.8.2-Linux-x86_64.sh  sample_data
# plot_bioactivity_class.pdf

# %%
# !mkdir -p "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %%
df = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/data2/bioactivity_data.csv")

# %%
import pandas as pd

# Example definition of bioactivity_threshold
# This should be replaced with your actual logic to determine active/inactive classes
bioactivity_threshold = ['active', 'inactive', 'inactive', 'active', 'inactive']  # Example data

# Assuming df4 is your existing DataFrame
df4 = pd.DataFrame({'some_data': [1, 2, 3, 4, 5]})  # Example DataFrame for demonstration

# Create the bioactivity_class Series
bioactivity_class = pd.Series(bioactivity_threshold, name='class')

# Concatenate the Series with the DataFrame
df5 = pd.concat([df4, bioactivity_class], axis=1)

# Check the unique values in the 'class' column
unique_classes = df5['class'].unique()

# Print the unique classes to see if there are active and inactive data
print("Unique bioactivity classes:", unique_classes)

# Check for the presence of 'active' and 'inactive'
if 'active' in unique_classes and 'inactive' in unique_classes:
    print("Both active and inactive data are present.")
elif 'active' in unique_classes:
    print("Only active data is present.")
elif 'inactive' in unique_classes:
    print("Only inactive data is present.")
else:
    print("Neither active nor inactive data is present.")
# Out:
# Unique bioactivity classes: ['active' 'inactive']
# Both active and inactive data are present.

# %% [markdown]
# # Calculate Lipinski descriptoers
#
# Christopher Lipinski, a former scientist at Pfizer, developed a set of guidelines known as the "***Rule of Five***" (or Lipinski's Rule of Five) to evaluate the **drug-likeness** of a compound. These guidelines are widely used in the pharmaceutical industry and medicinal chemistry to assess the potential for a compound to become an orally active drug.
# The Lipinski's Rule of Five states that a compound is more likely to be an orally active drug if it follows the following criteria:
#
#
# *   Molecular weight (MW) is less than 500 daltons.
# *   The compound should have no more than 5 hydrogen bond donors (such as –OH or –NH groups).
# *
# The compound should have no more than 10 hydrogen bond acceptors (such as N and O atoms).
#
# *   The compound's calculated Log P (the partition coefficient between n-octanol and water) value should be less than 5.
#
# These guidelines are based on the observation that most successful oral drugs have physicochemical properties that fall within these ranges. Compounds that violate more than one of these rules are less likely to be developed into successful oral drugs.
# The Rule of Five helps medicinal chemists and drug discovery scientists to prioritize and select the most promising drug candidates for further development, as it provides a quick way to evaluate the drug-likeness and potential for oral bioavailability of a given compound.

# %% [markdown]
# # Import libraries

# %%
# !apt-get update
# !apt-get install -y libstdc++6
# Out:
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-private.so.0.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-pkg.so.6.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-private.so.0.0)
# apt-get: /usr/local/lib/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libapt-pkg.so.6.0)

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# #Calculate descriptors

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski # Import Lipinski module
import pandas as pd # Import pandas

# Rename the function to avoid name conflict with the Lipinski module
def calculate_lipinski_descriptors(SMILES, verbose=False):
    moldata= []
    for elem in SMILES:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)
    baseData= np.arange(1,1)
    i=0
    for mol in moldata:
        desc_MolWt = Descriptors.MolWt(mol) # Use the imported Descriptors object
        desc_MolLogP = Descriptors.MolLogP(mol)
        # Call NumHDonors and NumHAcceptors as functions from the Lipinski module
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]
    descriptors_df = pd.DataFrame(data=baseData,columns=columnNames) # Rename to avoid conflict
    return descriptors_df # Return the DataFrame

# %%
df_lipinski = calculate_lipinski_descriptors(df.canonical_smiles) # Call the correct function name

# %% [markdown]
# #Combine DataFrames
# take a look at the 2 DataFrames that will be combind.

# %%
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    580.682  2.68582         3.0            8.0
# 1    547.653  1.39862         4.0            8.0
# 2    581.670  1.59522         4.0            8.0
# 3    659.781  0.87060         6.0            9.0
# 4    625.764  0.67400         6.0            9.0
# ..       ...      ...         ...            ...
# 210  668.767 -2.95720         4.0           10.0
# 211  524.659  2.51690         3.0            7.0
# 212  628.721 -1.81440         4.0           10.0
# 213  468.551  0.95810         3.0            7.0
# 214  572.613 -3.37320         4.0           10.0
#
# [215 rows x 4 columns]

# %%
df
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0            NaN              NaN      1988091                  []
# 1            NaN              NaN      1988092                  []
# 2            NaN              NaN      1988093                  []
# 3            NaN              NaN      1988094                  []
# 4            NaN              NaN      1988095                  []
# ..           ...              ...          ...                 ...
# 210          NaN              NaN     18548176                  []
# 211          NaN              NaN     18548177                  []
# 212          NaN              NaN     18548178                  []
# 213          NaN              NaN     18548179                  []
# 214          NaN              NaN     18548180                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL898907  Inhibition of SARS-CoV 3C-like protease by FRE...
# ...

# %%
df_combined = pd.concat([df,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0            NaN              NaN      1988091                  []
# 1            NaN              NaN      1988092                  []
# 2            NaN              NaN      1988093                  []
# 3            NaN              NaN      1988094                  []
# 4            NaN              NaN      1988095                  []
# ..           ...              ...          ...                 ...
# 210          NaN              NaN     18548176                  []
# 211          NaN              NaN     18548177                  []
# 212          NaN              NaN     18548178                  []
# 213          NaN              NaN     18548179                  []
# 214          NaN              NaN     18548180                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL898907  Inhibition of SARS-CoV 3C-like protease by FRE...
# ...

# %% [markdown]
# #Convert IC50 TO pIC50
# To allow IC50 data to be more uniformly disrtibuted, we will convert **IC50** to the nagative logarithmic scale wich is essentially -log10(IC150).
# This cutom function oIC50() will accept a DataFrame as input and will:
#
#
# *   Take the IC50 values from the stander_value column and converts it from nM to M by multiplying value by 10^(-9).
# *   Take the molar value and apply -log10.
#
#
# * Delete the *stander_value* column and creat a new pIC50 column.

# %%
import numpy as np
def pIC50(input):
    pIC50 = []
    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))
    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
    return x

# %% [markdown]
# Point the note: Values geater 100,000,000 will be fixed at 100,000,000 otherwise the ngative logarithmic value will become negative

# %%
df_combined.standard_value.describe() # Changed 'stander_value' to 'standard_value'
# Out:
# count       214.000000
# mean      55138.037383
# std       96554.024824
# min         160.000000
# 25%        8900.000000
# 50%       28500.000000
# 75%       50000.000000
# max      870000.000000
# Name: standard_value, dtype: float64

# %%
-np.log10((100**-9)* 100000000)
# Out:
# 10.0

# %%
-np.log10((10**-9)*10000000000)
# Out:
# -1.0

# %%
def norm_value(input):
  norm =[]
  for i in input['standard_value']:
    if i > 100000000:
      i = 100000000
    norm.append(i)
  input['standard_value_norm'] = norm
  x = input.drop('standard_value', axis=1) # Changed: Explicitly using axis=1 to specify column drop
  # or
  # x = input.drop(columns=['standard_value']) # Alternative: Using columns= to specify column(s) to drop
  return x

# %% [markdown]
# We will first apply the norm_value()function so that the values in the standard_value column is normalized

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0            NaN              NaN      1988091                  []
# 1            NaN              NaN      1988092                  []
# 2            NaN              NaN      1988093                  []
# 3            NaN              NaN      1988094                  []
# 4            NaN              NaN      1988095                  []
# ..           ...              ...          ...                 ...
# 210          NaN              NaN     18548176                  []
# 211          NaN              NaN     18548177                  []
# 212          NaN              NaN     18548178                  []
# 213          NaN              NaN     18548179                  []
# 214          NaN              NaN     18548180                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL898907  Inhibition of SARS-CoV 3C-like protease by FRE...
# ...

# %%
df_norm.standard_value_norm.describe()
# Out:
# count       214.000000
# mean      55138.037383
# std       96554.024824
# min         160.000000
# 25%        8900.000000
# 50%       28500.000000
# 75%       50000.000000
# max      870000.000000
# Name: standard_value_norm, dtype: float64

# %%
def pIC50(input):
  """
  Calculates pIC50 values from standard values.

  Args:
    input: A pandas DataFrame containing standard values.

  Returns:
    A pandas DataFrame with pIC50 values and the standard values column dropped.
  """

  pIC50 = []
  for i in input['standard_value_norm']:
    molar = i * (10 ** -9)  # Converts nM to M
    if molar > 0:
      pIC50.append(-np.log10(molar))
    else:
      pIC50.append(np.nan)  # Handles cases where molar is 0
  input['pIC50'] = pIC50
  # Fix: Changed 1 to axis=1
  x = input.drop('standard_value_norm', axis=1)
  return x

# %%
df_norm.standard_value_norm.describe()
# Out:
# count       214.000000
# mean      55138.037383
# std       96554.024824
# min         160.000000
# 25%        8900.000000
# 50%       28500.000000
# 75%       50000.000000
# max      870000.000000
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0            NaN              NaN      1988091                  []
# 1            NaN              NaN      1988092                  []
# 2            NaN              NaN      1988093                  []
# 3            NaN              NaN      1988094                  []
# 4            NaN              NaN      1988095                  []
# ..           ...              ...          ...                 ...
# 210          NaN              NaN     18548176                  []
# 211          NaN              NaN     18548177                  []
# 212          NaN              NaN     18548178                  []
# 213          NaN              NaN     18548179                  []
# 214          NaN              NaN     18548180                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL898907  Inhibition of SARS-CoV 3C-like protease by FRE...
# ...

# %%
df_final.pIC50.describe()
# Out:
# count    214.000000
# mean       4.635885
# std        0.619425
# min        3.060481
# 25%        4.301030
# 50%        4.545166
# 75%        5.050691
# max        6.795880
# Name: pIC50, dtype: float64

# %% [markdown]
# # Removing the 'intermediate' bioactivity class
#
# > Add blockquote
#
#
# we will be removing the *intermediate* class from out data set

# %%
import pandas as pd

# ... (Your existing code, including the pIC50 function) ...

def classify_bioactivity(pIC50_value):
    """
    Classifies bioactivity based on pIC50 value using thresholds.

    Args:
        pIC50_value (float): The pIC50 value.

    Returns:
        str: The bioactivity class ('active', 'intermediate', or 'inactive').
    """
    if pIC50_value >= 6: # Fixed indentation here
        return 'active'
    elif pIC50_value >= 5: # Fixed indentation here
        return 'intermediate'
    else: # Fixed indentation here
        return 'inactive'

def pIC50_with_bioactivity_class(df_norm):
    """
    Calculates pIC50 and assigns bioactivity class.

    Args:
        df_norm (pd.DataFrame): The normalized DataFrame.

    Returns:
        pd.DataFrame: The DataFrame with pIC50 and bioactivity_class columns.
    """
    # ... (Your existing pIC50 calculation logic here) ...

    # Add 'bioactivity_class' column
    df_final['bioactivity_class'] = df_final['pIC50'].apply(classify_bioactivity)

    return df_final

# Now use this modified function to create df_final
df_final = pIC50_with_bioactivity_class(df_norm)

# Filter the DataFrame
df_2class = df_final[df_final.bioactivity_class != 'intermediate']

# %%
df_2class = df_final[df_final.bioactivity_class != 'intermediate']
df_2class
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0            NaN              NaN      1988091                  []
# 1            NaN              NaN      1988092                  []
# 2            NaN              NaN      1988093                  []
# 3            NaN              NaN      1988094                  []
# 5            NaN              NaN      1988096                  []
# ..           ...              ...          ...                 ...
# 197          NaN              NaN     16602557                  []
# 200          NaN              NaN     16621214                  []
# 202          NaN              NaN     16621236                  []
# 205          NaN              NaN     18548171                  []
# 206          NaN              NaN     18548172                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL898907  Inhibition of SARS-CoV 3C-like protease by FRE...
# ...

# %% [markdown]
# # Remove rows with NaN values in 'pIC50'

# %%
df_final_cleaned = df_final.dropna(subset=['pIC50'])

# %%
# Fill NaN values with the mean of the column
mean_value = df_final['pIC50'].mean()
df_final['pIC50'].fillna(mean_value, inplace=True)

# Alternatively, fill with the median
# median_value = df_final['pIC50'].median()
# df_final['pIC50'].fillna(median_value, inplace=True)
# Out:
# <ipython-input-36-48a45daa2468>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_final['pIC50'].fillna(mean_value, inplace=True)

# %%
from sklearn.impute import SimpleImputer

# Create an imputer object with a strategy (mean, median, etc.)
imputer = SimpleImputer(strategy='mean')

# Reshape data if necessary and fit the imputer
df_final['pIC50'] = imputer.fit_transform(df_final[['pIC50']])

# %%
import pandas as pd

# Sample DataFrame
data = {'pIC50': [7.5, 8.0, None, 6.3, None, 5.5]}
df_final = pd.DataFrame(data)

# Check for NaN values
nan_count = df_final['pIC50'].isna().sum()
print(f'Number of NaN values in pIC50: {nan_count}')

# Option 1: Remove rows with NaN values
df_final_cleaned = df_final.dropna(subset=['pIC50'])

# Option 2: Fill NaN values with the mean
mean_value = df_final['pIC50'].mean()
df_final['pIC50'].fillna(mean_value, inplace=True)

# Print the cleaned DataFrame
print(df_final)
# Out:
# Number of NaN values in pIC50: 2
#    pIC50
# 0  7.500
# 1  8.000
# 2  6.825
# 3  6.300
# 4  6.825
# 5  5.500
# <ipython-input-38-ceedd6c52d0e>:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_final['pIC50'].fillna(mean_value, inplace=True)

# %%
# Check for NaN values in 'pIC50' column again
nan_count_after_removal = df_final['pIC50'].isna().sum()
print(f'Number of NaN values in pIC50 after removal: {nan_count_after_removal}')
# Out:
# Number of NaN values in pIC50 after removal: 0

# %% [markdown]
# #Import library

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %% [markdown]
# # Frequency plot of the 2 bioactivity classes

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame creation (replace this with your actual DataFrame)
data = {
    'bioactivity_class': ['active', 'inactive', 'active', 'inactive', 'active', 'inactive', 'active']
}
df_2class = pd.DataFrame(data)

# Define colors for each class
color_mapping = {'active': 'green', 'inactive': 'red'}

# Create the countplot with the specified colors
plt.figure(figsize=(5.5, 5.5))
sns.countplot(x='bioactivity_class', data=df_2class, edgecolor='black', palette=color_mapping)

# Set labels
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

# Save the plot
plt.savefig('plot_bioactivity_class.pdf')
plt.show()  # Optional: Show the plot
# Out:
# <ipython-input-63-596e4258828a>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='bioactivity_class', data=df_2class, edgecolor='black', palette=color_mapping)

# %% [markdown]
# #Scatter plot of MW versus LogP

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame creation (replace this with your actual DataFrame)
data = {
    'MW': [200, 250, 300, 150, 400, 350, 450],
    'LogP': [1.5, 2.0, 3.5, 0.5, 4.0, 2.5, 3.0],
    'bioactivity_class': ['active', 'inactive', 'active', 'inactive', 'active', 'inactive', 'active'],
    'pIC50': [5.0, 3.0, 4.5, 2.5, 6.0, 3.5, 4.0]
}
df_2class = pd.DataFrame(data)

# Define colors for each class
color_mapping = {'active': 'green', 'inactive': 'red'}

# Create the scatter plot with the specified colors
plt.figure(figsize=(5.5, 5.5))
sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='bioactivity_class',
                size='pIC50', sizes=(50, 500), palette=color_mapping,
                edgecolor='black', alpha=0.7)

# Set labels
plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

# Customize the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

# Save the plot
plt.savefig('plot_MW_vs_LogP.pdf')
plt.show()  # Optional: Show the plot

# %% [markdown]
# #Box plots
#
# pIC50 value

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame creation (replace this with your actual DataFrame)
data = {
    'bioactivity_class': ['active', 'inactive', 'active', 'inactive', 'active', 'inactive', 'active'],
    'pIC50': [5.0, 3.0, 4.5, 2.5, 6.0, 3.5, 4.0]
}
df_2class = pd.DataFrame(data)

# Define colors for each class
color_mapping = {'active': 'green', 'inactive': 'red'}

# Create the box plot with the specified colors
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x='bioactivity_class', y='pIC50', data=df_2class, palette=color_mapping)

# Set labels
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

# Save the plot
plt.savefig('plot_ic50.pdf')
plt.show()  # Optional: Show the plot
# Out:
# <ipython-input-65-625383801511>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='bioactivity_class', y='pIC50', data=df_2class, palette=color_mapping)

# %% [markdown]
# # Statistical analysis | Mann-Whitney U Test

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  active = df[df.bioactivity_class == 'active']
  active = active[descriptor]

  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  inactive = df[df.bioactivity_class == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'

  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
import pandas as pd
from scipy import stats

# Example DataFrame
data = {
    'pIC50': [7.500, 8.000, 6.825, 6.300, 6.825, 5.500],
    'group_column': ['Group1', 'Group1', 'Group1', 'Group2', 'Group2', 'Group2']
}
df_final = pd.DataFrame(data)

# Split into groups
group1 = df_final[df_final['group_column'] == 'Group1']['pIC50']
group2 = df_final[df_final['group_column'] == 'Group2']['pIC50']

# Check for NaN values
print(f'NaN values in Group 1: {group1.isna().sum()}')
print(f'NaN values in Group 2: {group2.isna().sum()}')

# Perform the Mann-Whitney U test
u_statistic, p_value = stats.mannwhitneyu(group1, group2, alternative='two-sided')

# Prepare the output DataFrame
results = pd.DataFrame({
    'Descriptor': ['pIC50'],
    'Statistics': [u_statistic],
    'p': [p_value],
    'alpha': [0.05],
    'Interpretation': ['Different distribution (reject H0)' if p_value < 0.05 else 'No significant difference (fail to reject H0)']
})

# Display the results DataFrame
print(results)
# Out:
# NaN values in Group 1: 0
# NaN values in Group 2: 0
#   Descriptor  Statistics         p  alpha  \
# 0      pIC50         8.5  0.121183   0.05
#
#                                   Interpretation
# 0  No significant difference (fail to reject H0)

# %% [markdown]
# #MW

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame creation (replace this with your actual DataFrame)
data = {
    'bioactivity_class': ['active', 'inactive', 'active', 'inactive', 'active', 'inactive', 'active'],
    'MW': [200, 300, 250, 400, 350, 450, 500]
}
df_2class = pd.DataFrame(data)

# Define colors for each class
color_mapping = {'active': 'green', 'inactive': 'red'}

# Create the box plot with the specified colors
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x='bioactivity_class', y='MW', data=df_2class, palette=color_mapping)

# Set labels
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

# Save the plot
plt.savefig('plot_MW.pdf')
plt.show()  # Optional: Show the plot
# Out:
# <ipython-input-66-0872caea2ed7>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='bioactivity_class', y='MW', data=df_2class, palette=color_mapping)

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0         MW       408.5  0.820412   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #LogP

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame creation (replace this with your actual DataFrame)
data = {
    'bioactivity_class': ['active', 'inactive', 'active', 'inactive', 'active', 'inactive', 'active'],
    'LogP': [1.5, 2.5, 3.0, 1.0, 4.0, 2.0, 3.5]
}
df_2class = pd.DataFrame(data)

# Define colors for each class
color_mapping = {'active': 'green', 'inactive': 'red'}

# Create the box plot with the specified colors
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x='bioactivity_class', y='LogP', data=df_2class, palette=color_mapping)

# Set labels
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

# Save the plot
plt.savefig('plot_LogP.pdf')
plt.show()  # Optional: Show the plot
# Out:
# <ipython-input-67-98ba4d2585fa>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='bioactivity_class', y='LogP', data=df_2class, palette=color_mapping)

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0       LogP       338.5  0.649808   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #NumHDonors

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame creation (replace this with your actual DataFrame)
data = {
    'bioactivity_class': ['active', 'inactive', 'active', 'inactive', 'active', 'inactive', 'active'],
    'NumHDonors': [1, 3, 2, 4, 1, 2, 3]
}
df_2class = pd.DataFrame(data)

# Define colors for each class
color_mapping = {'active': 'green', 'inactive': 'red'}

# Create the box plot with the specified colors
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x='bioactivity_class', y='NumHDonors', data=df_2class, palette=color_mapping)

# Set labels
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

# Save the plot
plt.savefig('plot_NumHDonors.pdf')
plt.show()  # Optional: Show the plot
# Out:
# <ipython-input-68-3e25db4583c4>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='bioactivity_class', y='NumHDonors', data=df_2class, palette=color_mapping)

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics        p  alpha  \
# 0  NumHDonors       341.5  0.66417   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #NumHAcceptors

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame creation (replace this with your actual DataFrame)
data = {
    'bioactivity_class': ['active', 'inactive', 'active', 'inactive', 'active', 'inactive', 'active'],
    'NumHAcceptors': [2, 4, 3, 5, 2, 3, 4]
}
df_2class = pd.DataFrame(data)

# Define colors for each class
color_mapping = {'active': 'green', 'inactive': 'red'}

# Create the box plot with the specified colors
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x='bioactivity_class', y='NumHAcceptors', data=df_2class, palette=color_mapping)

# Set labels
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

# Save the plot
plt.savefig('plot_NumHAcceptors.pdf')
plt.show()  # Optional: Show the plot
# Out:
# <ipython-input-69-ef0653a4af05>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='bioactivity_class', y='NumHAcceptors', data=df_2class, palette=color_mapping)

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics         p  alpha  \
# 0  NumHAcceptors       334.0  0.612915   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# #Interpretation of Statistical Results
# #Box Plots
#
# pIC50 values
# **bold text**
# Taking a look at pIC50 values, the actives and inactives displayed statistically significant difference, which is to be expected since threshold values (IC50 < 1,000 nM = Actives while IC50 > 10,000 nM = Inactives, corresponding to pIC50 > 6 = Actives and pIC50 < 5 = Inactives) were used to define actives and inactives.
#
# Lipinski's descriptors
#
# Of the 4 Lipinski's descriptors (MW, LogP, NumHDonors and NumHAcceptors), only LogP exhibited no difference between the actives and inactives while the other 3 descriptors (MW, NumHDonors and NumHAcceptors) shows statistically significant difference between actives and inactives.

# %% [markdown]
# #Zip files

# %%
! zip -r results.zip . -i *.csv *.pdf
# Out:
# 	zip warning: name not matched: gdrive
#   adding: plot_ic50.pdf (deflated 37%)
#   adding: plot_MW.pdf (deflated 38%)
#   adding: plot_NumHAcceptors.pdf (deflated 38%)
#   adding: mannwhitneyu_MW.csv (deflated 8%)
#   adding: plot_MW_vs_LogP_with_intermediate.pdf (deflated 15%)
#   adding: mannwhitneyu_NumHDonors.csv (deflated 10%)
#   adding: mannwhitneyu_pIC50.csv (deflated 9%)
#   adding: mannwhitneyu_LogP.csv (deflated 7%)
#   adding: plot_MW_vs_LogP.pdf (deflated 13%)
#   adding: plot_NumHDonors.pdf (deflated 37%)
#   adding: plot_bioactivity_class.pdf (deflated 37%)
#   adding: mannwhitneyu_NumHAcceptors.csv (deflated 10%)
#   adding: plot_LogP.pdf (deflated 38%)
